# %% [markdown]
# # Tamura Features for CBIR system
# ---

# %% [markdown]
# **Author:** Abhishek Singh
# **Description:** Six Tamura features used for the Content Based Image Retrieval System
# ___

# %% [markdown]
# ## Import Libraries

# %%
import os
import scipy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage import io
from skimage.feature import greycomatrix

# %matplotlib inline

# %%
from scipy.signal import find_peaks_cwt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Images

# %%
img_path = 'OriginalBrodatz/'

# %%
def load_image_dir(path):
    images = []
    filenames = []
    for filename in os.listdir(path):
        filenames.append(os.path.join(path,filename))
        img = io.imread(os.path.join(path,filename))
        if img is not None:
            images.append(img)
    return images, filenames

# %%
images, filenames = load_image_dir(img_path)
print('Loaded {} images from {} \nDisplaying a sample...'.format(len(images), img_path))
io.imshow(images[10])
# Out:
# Loaded 50 images from OriginalBrodatz/
# Displaying a sample...

# %% [markdown]
# ## Tamura Features

# %% [markdown]
# ### Peak Detection Utility

# %%
def peakdet_(sig=None,th=None,typ=None,mdist=None,*args,**kwargs):
#     varargin = cellarray(args)
#     nargin = 4-[sig,th,_type,mdist].count(None)+len(args)

    pks=np.array([])
    dep=np.array([])
    pid=np.array([])
    did=np.array([])
    m,n=np.shape(sig)
    
    if m == 1 and n > 1:
        sig=sig.T
        m,n=np.shape(sig)

#     if nargin < 2:
#         th=0.5

    if len(th) > 1:
        raise ValueError('Input argument th (threshold) must be a scalar')
    if th <= 0:
        raise ValueError('Input argument th (threshold) must be positive')
    if typ is not None and var is not None:
        typ='threshold'
    if mdist is not None and var is not None:
        mdist=0
    if type(typ) is not str:
        raise ValueError('Input argument type must be string "threshold" or "zero"')
    if strcmp_(_type,char('threshold')) or strcmp_(_type,char('th')):
        cross=copy_(th)
    else:
        if strcmp_(_type,char('zero')):
            cross=0
        else:
            error_(char('Input argument type must be string "threshold" or "zero"'))
    mn=copy_(Inf)
    mx=- Inf
    mnpos=copy_(NaN)
    mxpos=copy_(NaN)
    idx=find_(sig > th,1,char('first'))
    idn=find_(sig < th,1,char('first'))
    if idx < idn:
        lookpks=copy_(true)
    else:
        lookpks=copy_(false)
    for ii in arange_(1,m).reshape(-1):
        this=sig[ii]
        if this > mx:
            mx=copy_(this)
            mxpos=copy_(ii)
        if this < mn:
            mn=copy_(this)
            mnpos=copy_(ii)
        if lookpks:
            if this < cross:
                if mx >= th:
                    pks=matlabarray([[pks],[mx]])
                    pid=matlabarray([[pid],[mxpos]])
                mn=copy_(this)
                mnpos=copy_(ii)
                lookpks=copy_(false)
        else:
            if this > - cross:
                if mn <= - th:
                    dep=matlabarray([[dep],[mn]])
                    did=matlabarray([[did],[mnpos]])
                mx=copy_(this)
                mxpos=copy_(ii)
                lookpks=copy_(true)
    if lookpks:
        if mx >= th:
            pks=matlabarray([[pks],[mx]])
            pid=matlabarray([[pid],[mxpos]])
    else:
        if mn <= - th:
            dep=matlabarray([[dep],[mn]])
            did=matlabarray([[did],[mnpos]])
    if (mdist > 0):
        val,subidx=sort_(pks,char('descend'),nargout=2)
        idx=pid[subidx]
        todelete=false_(size_(val))
        N=length_(val)
        for ii in arange_(1,N).reshape(-1):
            if not todelete[ii]:
                d=arrayfun_(lambda x: norm_(x - idx[ii]),idx)
                todelete=todelete or (d < mdist)
                todelete[ii]=false
        pks[subidx[todelete]]=[]
        pid[subidx[todelete]]=[]
        val,subidx=sort_(dep,nargout=2)
        idx=did[subidx]
        todelete=false_(size_(val))
        N=length_(val)
        for ii in arange_(1,N).reshape(-1):
            if not todelete[ii]:
                d=arrayfun_(lambda x: norm_(x - idx[ii]),idx)
                todelete=todelete or (d < mdist)
                todelete[ii]=false
        dep[subidx[todelete]]=[]
        did[subidx[todelete]]=[]
    return pks,dep,pid,did

# %% [markdown]
# ### Coarseness

# %%
def coarseness(img):
    [r,c] = img.shape
    G = np.copy(img)
    #initialization
    #Average of neighbouring pixels
    A1=np.zeros([r,c])
    A2=np.zeros([r,c])
    A3=np.zeros([r,c])
    A4=np.zeros([r,c])
    A5=np.zeros([r,c])
    A6=np.zeros([r,c])
    #Sbest for coarseness
    Sbest=np.zeros([r,c])
    #Subtracting for Horizontal and Vertical case
    E1h=np.zeros([r,c])
    E1v=np.zeros([r,c])
    E2h=np.zeros([r,c])
    E2v=np.zeros([r,c])
    E3h=np.zeros([r,c])
    E3v=np.zeros([r,c])
    E4h=np.zeros([r,c])
    E4v=np.zeros([r,c])
    E5h=np.zeros([r,c])
    E5v=np.zeros([r,c])
    E6h=np.zeros([r,c])
    E6v=np.zeros([r,c])
    # to avoid errors
    flag=0
    
    #2x2  E1h and E1v
    #subtracting average of neighbouring 2x2 pixels 
    for x in range(1,r):
        for y in range(1,c):
            A1[x,y] = np.sum(np.sum(G[x-1:x,y-1:y]))
    for x in range(1,r-1):
        for y in range(1,c-1):
            E1h[x,y] = A1[x+1,y] - A1[x-1,y]
            E1v[x,y] = A1[x,y+1] - A1[x,y-1]
    E1h = E1h/2**(2*1)
    E1v = E1v/2**(2*1)
     
    # 4x4  E2h and E2v
    if (r<4 or c<4):
        flag=1
        
    #subtracting average of neighbouring 4x4 pixels
    if flag is 0:
        for x in range(2,r-1):
            for y in range(2,c-1):
                A2[x,y]= np.sum(np.sum(G[x-2:x+1,y-2:y+1]))
        for x in range(2,r-2):
            for y in range(2,c-2):
                E2h[x,y] = A2[x+2,y] - A2[x-2,y]
                E2v[x,y] = A2[x,y+2] - A2[x,y-2]
    E2h = E2h/2**(2*2)
    E2v = E2v/2**(2*2)
    
    #8x8 E3h and E3v
    if r<8 or c<8:
        flag=1
    #subtracting average of neighbouring 8x8 pixels
    if flag is 0:
        for x in range(4,r-3):
            for y in range(4,c-3):
                A3[x,y]=np.sum(np.sum(G[x-4:x+3,y-4:y+3]))
        for x in range(4,r-4):
            for y in range(4,c-4):
                E3h[x,y] = A3[x+4,y]-A3[x-4,y]
                E3v[x,y] = A3[x,y+4]-A3[x,y-4]
    
    E3h=E3h/2**(2*3)
    E3v=E3v/2**(2*3)
    
#     io.imshow(img)
#     io.imshow(E1h)
#     io.imshow(E1v)
    
    #at each point pick best size "Sbest", which gives highest output value
    for i in range(r):
        for j in range(c):
            maxv = np.max([np.abs(E1h[i,j]),np.abs(E1v[i,j]),np.abs(E2h[i,j]),np.abs(E2v[i,j]),np.abs(E3h[i,j]),np.abs(E3v[i,j])])
            index = np.argmax([np.abs(E1h[i,j]),np.abs(E1v[i,j]),np.abs(E2h[i,j]),np.abs(E2v[i,j]),np.abs(E3h[i,j]),np.abs(E3v[i,j])])
            #'k'corresponding to highest E in either direction
            k=np.floor((index+1)/2)
            Sbest[i,j]=2**k
#     print('Output of best size detector \n{}'.format(Sbest))
    # Coarseness Value
    Fcoarseness=np.sum(np.sum(Sbest))/(r*c)
    return Fcoarseness

# %%
coarseness(images[0])
# Out:
# 4.8468457031250001

# %% [markdown]
# ### Contrast

# %%
def contrast(img):
    flat_img = img.ravel()
    std = np.std(flat_img)
    kurtosis = sp.stats.moment(flat_img, moment=4)
    contrast = std/((kurtosis/std**4)**0.25)
    return contrast

# %%
contrast(images[0])
# Out:
# 28.51568627590342

# %% [markdown]
# ### Directionality

# %%
def directionality(img):
    r, c = img.shape
    G = np.copy(img)
    # for measuring horizontal differences
    PrewittH = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
    # for measuring vertical differences
    PrewittV = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
    # Applying PerwittH operator
    deltaH=np.zeros(img.shape)
    for i in range(1,r-1):
        for j in range(1,c-1):
            deltaH[i,j]= np.sum(np.sum(G[i-1:i+2,j-1:j+2]*PrewittH))

    # Modifying borders
    for j in range(1,c-1):
        deltaH[0,j]=G[0,j+1]-G[0,j]
        deltaH[r-1,j]=G[r-1,j+1]-G[r-1,j]  
    for i in range(0,r):
        deltaH[i,1]=G[i,2]-G[i,1]
        deltaH[i,c-1]=G[i,c-1]-G[i,c-2]  

    # Applying PerwittV operator
    deltaV=np.zeros(img.shape)
    for i in range(1,r-1):
        for j in range(1,c-1):
            deltaV[i,j]=np.sum(np.sum(G[i-1:i+2,j-1:j+2]*PrewittV))
        
    # Modifying borders
    for j in range(0,c):
        deltaV[0,j-1]=G[1,j-1]-G[0,j-1]
        deltaV[r-1,j-1]=G[r-1,j-1]-G[r-2,j-1]  
    for i in range(2,r-1):
        deltaV[i-1,0]=G[i,0]-G[i-1,0]
        deltaV[i-1,c-1]=G[i,c-1]-G[i-1,c-1]  
        
    # Magnitude
    deltaG=(np.abs(deltaH)+np.abs(deltaV))/2

    # Local edge direction (0<=theta<pi)
    theta=np.zeros(img.shape)
    for i in range(0,r):
        for j in range(0,c):
            if deltaH[i,j]==0 and deltaV[i,j]==0:
                theta[i,j]=0
            elif deltaH[i,j]==0:
                theta[i,j]=np.pi           
            else:          
                theta[i,j]=np.arctan(deltaV[i,j]/deltaH[i,j]) + np.pi/2

    deltaGt = np.copy(deltaG)
    theta1=np.copy(theta)

    # Set a Threshold value for delta G
    n = 16
    HD = np.zeros([n])
    Threshold=12
    counti=0
    for m in range(-1,(n-1)):
        countk=0
        for k in range(0,len(deltaGt)):
            if ((np.any(deltaGt[k])>=Threshold)
                and (np.any(theta1[k])>=(2*m-1)*np.pi/(2*n))
                and (np.any(theta1[k])<(2*m+1)*np.pi/(2*n))):
                countk=countk+1
                counti=counti+1
        HD[m+1] = countk
    HDf = HD/counti
    
    # peakdet function to find peak values
    #m, p = octave.peakdet(sig=HDf,th=0.000005)
    #(m, p, pidx, didx) = octave.peakdet(sig=HDf)
    m = find_peaks_cwt(HDf, np.arange(1,2))
    Fd=0
    for NP in range(0, len(m)):
        phaiP=m[NP]*(np.pi/n)
        for phi in range(0,len(HDf)):
                Fd=Fd+(phi*(np.pi/n)-phaiP)^2*HDf(phi);

    r = 1/n
    Fdirection = 1 - r*len(m)*Fd
    return Fdirection

# %% [markdown]
# ## Tamura Feature Generation

# %%
feature_set = pd.DataFrame(columns=['Image', 'Coarseness','Contrast', 'Directionality'])
for img, name in zip(images, filenames):
    row = {'Image': name,
          'Coarseness': coarseness(img),
          'Contrast': contrast(img),
          'Directionality': directionality(img),}
    print('Processed Image {}'.format(name), end='\r')
    feature_set = feature_set.append(row, ignore_index=True)
print('Done')
# Out:
# Doneessed Image OriginalBrodatz/D8.giff

# %% [markdown]
# ## Visualizations

# %%
from IPython.core.display import display, HTML
feature_set.loc[:,'Image'] = ["<img src='{}' width='50' height='50'>".format(i) for i in feature_set['Image']]
display(HTML(feature_set.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Coarseness</th>
#       <th>Contrast</th>
#       <th>Directionality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src='OriginalBrodatz/D1.gif' width='50' h...</td>
#       <td>4.846846</td>
#       <td>28.515686</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src='OriginalBrodatz/D10.gif' width='50' ...</td>
#       <td>4.684463</td>
#       <td>35.447898</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='OriginalBrodatz/D11.gif' width='50' ...</td>
#       <td>4.758682</td>
#       <td>45.650797</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='OriginalBrodatz/D12.gif' width='50' ...</td>
#       <td>5.351497</td>
#       <td>70.251523</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='OriginalBrodatz/D13.gif' width='50' ...</td>
#       <td>5.471147</td>
#       <td>62.333737</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='OriginalBrodatz/D14.gif' width='50' ...</td>
#       <td>3.406643</td>
#       <td>41.812273</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='OriginalBrodatz/D15.gif' width='50' ...</td>
#       <td>5.130061</td>
#       <td>59.330188</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='OriginalBrodatz/D17.gif' width='50' ...</td>
#       <td>3.448398</td>
#       <td>40.482823</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='OriginalBrodatz/D18.gif' width='50' ...</td>
#       <td>5.008677</td>
#       <td>47.489240</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='OriginalBrodatz/D19.gif' width='50' ...</td>
#       <td>4.777422</td>
#       <td>34.997705</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src='OriginalBrodatz/D2.gif' width='50' h...</td>
#       <td>5.181509</td>
#       <td>49.842117</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src='OriginalBrodatz/D20.gif' width='50' ...</td>
#       <td>5.044229</td>
#       <td>78.479964</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src='OriginalBrodatz/D21.gif' width='50' ...</td>
#       <td>2.428423</td>
#       <td>49.854760</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src='OriginalBrodatz/D22.gif' width='50' ...</td>
#       <td>4.702656</td>
#       <td>61.778678</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src='OriginalBrodatz/D23.gif' width='50' ...</td>
#       <td>5.343408</td>
#       <td>57.327672</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src='OriginalBrodatz/D24.gif' width='50' ...</td>
#       <td>4.356128</td>
#       <td>56.511248</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src='OriginalBrodatz/D25.gif' width='50' ...</td>
#       <td>4.367759</td>
#       <td>18.121061</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src='OriginalBrodatz/D26.gif' width='50' ...</td>
#       <td>3.959592</td>
#       <td>34.242800</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src='OriginalBrodatz/D27.gif' width='50' ...</td>
#       <td>5.343933</td>
#       <td>52.291510</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src='OriginalBrodatz/D28.gif' width='50' ...</td>
#       <td>5.079875</td>
#       <td>40.396768</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><img src='OriginalBrodatz/D29.gif' width='50' ...</td>
#       <td>4.247058</td>
#       <td>27.204295</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><img src='OriginalBrodatz/D3.gif' width='50' h...</td>
#       <td>3.880525</td>
#       <td>50.724042</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td><img src='OriginalBrodatz/D30.gif' width='50' ...</td>
#       <td>5.443291</td>
#       <td>62.685448</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td><img src='OriginalBrodatz/D31.gif' width='50' ...</td>
#       <td>5.141257</td>
#       <td>65.604601</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td><img src='OriginalBrodatz/D32.gif' width='50' ...</td>
#       <td>4.225549</td>
#       <td>11.616193</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td><img src='OriginalBrodatz/D33.gif' width='50' ...</td>
#       <td>4.734265</td>
#       <td>13.517786</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td><img src='OriginalBrodatz/D34.gif' width='50' ...</td>
#       <td>4.042561</td>
#       <td>15.640976</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td><img src='OriginalBrodatz/D36.gif' width='50' ...</td>
#       <td>5.094705</td>
#       <td>64.491691</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td><img src='OriginalBrodatz/D37.gif' width='50' ...</td>
#       <td>3.831152</td>
#       <td>29.846149</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td><img src='OriginalBrodatz/D38.gif' width='50' ...</td>
#       <td>3.683882</td>
#       <td>49.438948</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td><img src='OriginalBrodatz/D39.gif' width='50' ...</td>
#       <td>4.824780</td>
#       <td>18.086933</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td><img src='OriginalBrodatz/D4.gif' width='50' h...</td>
#       <td>4.075574</td>
#       <td>46.565473</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td><img src='OriginalBrodatz/D40.gif' width='50' ...</td>
#       <td>4.625442</td>
#       <td>34.494291</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td><img src='OriginalBrodatz/D41.gif' width='50' ...</td>
#       <td>3.897083</td>
#       <td>34.997241</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td><img src='OriginalBrodatz/D42.gif' width='50' ...</td>
#       <td>4.330845</td>
#       <td>62.010330</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td><img src='OriginalBrodatz/D43.gif' width='50' ...</td>
#       <td>4.335129</td>
#       <td>33.446981</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td><img src='OriginalBrodatz/D44.gif' width='50' ...</td>
#       <td>4.301299</td>
#       <td>32.955701</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td><img src='OriginalBrodatz/D45.gif' width='50' ...</td>
#       <td>4.639680</td>
#       <td>40.490719</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td><img src='OriginalBrodatz/D46.gif' width='50' ...</td>
#       <td>5.458828</td>
#       <td>47.062909</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td><img src='OriginalBrodatz/D47.gif' width='50' ...</td>
#       <td>4.812788</td>
#       <td>31.052538</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td><img src='OriginalBrodatz/D48.gif' width='50' ...</td>
#       <td>5.441111</td>
#       <td>58.099230</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td><img src='OriginalBrodatz/D49.gif' width='50' ...</td>
#       <td>2.132957</td>
#       <td>71.894588</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td><img src='OriginalBrodatz/D5.gif' width='50' h...</td>
#       <td>4.982693</td>
#       <td>53.253439</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td><img src='OriginalBrodatz/D50.gif' width='50' ...</td>
#       <td>6.016477</td>
#       <td>29.606454</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td><img src='OriginalBrodatz/D7.gif' width='50' h...</td>
#       <td>4.574622</td>
#       <td>55.845636</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td><img src='OriginalBrodatz/D9.gif' width='50' h...</td>
#       <td>4.098384</td>
#       <td>53.

# %% [markdown]
# ___
