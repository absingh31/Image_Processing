# %% [markdown]
# # Content Based Image Retrieval with Color Histograms
# ---

# %% [markdown]
# ---
# **Name : Aman Hussain**
# **Reg : 15BCE1077**
# **Description : Color Histogram Based Image Retrieval System**
# ___

# %% [markdown]
# ## Global Config

# %%
bins_list = [[8,8,8],
             [16,16,16],
             [32,32,32],
             [64,64,64]]

# %% [markdown]
# ## Instatiating CBIR Engine

# %%
from HistCBIR import HistCBIR

engine = HistCBIR(database='imageDB/', bins=bins_list[0])

# %% [markdown]
# ## Querying Image

# %%
engine.query(query='imageDB/blue.jpg', rank=10)
# Out:
# Processing Query Image...
# Searching...
# Displaying results...

# %% [markdown]
# ## Precision & Recall
# **With Variable Histogram Bin Sizes**

# %% [markdown]
# Precision-Recall graphs measure the accuracy of our image retrieval system. They are also used in the performance measurement of any other search engine.

# %% [markdown]
# **Precision**
# Precision is the total relevant images retrieved from a collection of relevant and irrelevant images. It denotes how _precise_ the system is in accurately retreiving useful results from an impure or noisy collection of items.
# ```
# precision = relevant_items_retrieved / (relevant_items + irrelevant_items)
# ```

# %% [markdown]
# **Recall**
# Recall is the ratio of the relevant images retrieved to all the relevant images in the database. It denotes the how well the system _recalls_ the relevant images from the all the existing relevant images.
# ```
# recall = relevant_items_retrieved / total_relevant_items
# ```

# %% [markdown]
# **Testing CBIR engine performance with Bin Size : 8**

# %%
engine8 = HistCBIR(database='imageDB/', bins=bins_list[0])
engine8.query(query='imageDB/blue.jpg', rank=3,
             precision_recall=True,
             relevant=['blue.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '20.jpg'])
# Out:
# Processing Query Image...
# Searching...
# Displaying results...

# %% [markdown]
# **Testing CBIR engine performance with Bin Size : 16**

# %%
engine16 = HistCBIR(database='imageDB/', bins=bins_list[1])
engine16.query(query='imageDB/blue.jpg', rank=3,
             precision_recall=True,
             relevant=['blue.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '20.jpg'])
# Out:
# Processing Query Image...
# Searching...
# Displaying results...

# %% [markdown]
# **Testing CBIR engine performance with Bin Size : 32**

# %%
engine32 = HistCBIR(database='imageDB/', bins=bins_list[2])
engine32.query(query='imageDB/blue.jpg', rank=3,
             precision_recall=True,
             relevant=['blue.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '20.jpg'])
# Out:
# Processing Query Image...
# Searching...
# Displaying results...

# %% [markdown]
# **Testing CBIR engine performance with Bin Size : 64**

# %%
engine64 = HistCBIR(database='imageDB/', bins=bins_list[3])
engine64.query(query='imageDB/blue.jpg', rank=3,
             precision_recall=True,
     
               relevant=['blue.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '20.jpg'])
# Out:
# Processing Query Image...
# Searching...
# Displaying results...
