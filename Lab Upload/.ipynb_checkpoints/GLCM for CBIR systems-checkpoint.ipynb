# %% [markdown]
# # Gray Level Co-occurence Matrix for CBIR systems
# ---

# %% [markdown]
# **Author:** Abhishek Singh
# **Description:** Texture features (energy, entropy, contrast, inverse difference moment) are computed from the gray level co-occurence matrix of images at a pixel distance of 1 across horizontal, vertical and diagonal axes
# ___

# %% [markdown]
# ## Import Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage import io
from skimage.feature import greycomatrix

# %matplotlib inline

# %% [markdown]
# ## Load Images

# %%
img_path = 'OriginalBrodatz/'

# %% [markdown]
# **Dataset Link** https://multibandtexture.recherche.usherbrooke.ca/original_brodatz.html

# %%
def load_image_dir(path):
    images = []
    filenames = []
    for filename in os.listdir(path):
        filenames.append(os.path.join(path,filename))
        img = io.imread(os.path.join(path,filename))
        if img is not None:
            images.append(img)
    return images, filenames

# %%
images, filenames = load_image_dir(img_path)
print('Loaded {} images from {} \nDisplaying a sample...'.format(len(images), img_path))
io.imshow(images[10])
# Out:
# Loaded 112 images from OriginalBrodatz/
# Displaying a sample...

# %% [markdown]
# ## Compute GLCM

# %%
distances = [1]
# horizontal, diagonal, vertical
angles = [0, np.pi/4, np.pi/2]

# %%
glcm_set = list()
for img in images:
    glcm_set.append(greycomatrix(img, distances,
                                 angles, symmetric=True,
                                 normed=True))

# %% [markdown]
# **Sample GLCM**

# %%
io.imshow(glcm_set[12][:,:,0,1])
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %% [markdown]
# ## Generate Features using GLCM

# %%
def glcm_features(glcm, feat='energy'):
    '''Calculate Texture Features of a GLCM
    
    Features
    --------
    energy
    entropy
    contrast
    inverse difference moment
    '''
    (num_level, num_level2, num_dist, num_angle) = glcm.shape
    assert num_level == num_level2
    assert num_dist > 0
    assert num_angle > 0
    
    # create weights for specified features
    I, J = np.ogrid[0:num_level, 0:num_level]
    if feat in ['contrast', 'inverse difference moment']:
        weights = (I - J) ** 2
        weights = weights.reshape((num_level, num_level, 1, 1))
    elif feat in ['energy', 'entropy']:
        pass
    else:
        raise ValueError('{} is an invalid property'.format(prop))
    
    # compute features for each GLCM
    if feat=='energy':
        asm = np.apply_over_axes(np.sum, (glcm**2),
                                 axes=(0,1))[0,0]
        results = np.sqrt(asm)
    elif feat=='entropy':
        results = np.apply_over_axes(np.sum, (glcm*np.ma.log(glcm)),
                                     axes=(0,1))[0,0]
    elif feat=='contrast':
        results = np.apply_over_axes(np.sum, (glcm * weights),
                                     axes=(0, 1))[0, 0]
    elif feat=='inverse difference moment':
        results = np.apply_over_axes(np.sum, (glcm/(1+weights)),
                                     axes=(0, 1))[0, 0]
    
    return np.round(results.ravel(), 3)

# %%
glcm_features(glcm_set[0], feat='inverse difference moment')
# Out:
# array([ 0.224,  0.202,  0.22 ])

# %%
feature_set = pd.DataFrame(columns=['Image', 'Contrast',
                                    'Inverse Difference Moment',
                                    'Energy', 'Entropy'])

# %% [markdown]
# **Begin Feature Generation**

# %%
for glcm, name in zip(glcm_set, filenames):
    row = {'Image': name,
          'Contrast': glcm_features(glcm, 'contrast'),
          'Inverse Difference Moment': glcm_features(glcm, 'inverse difference moment'),
          'Energy': glcm_features(glcm, 'energy'),
          'Entropy': glcm_features(glcm, 'entropy')}
    feature_set = feature_set.append(row, ignore_index=True)

# %% [markdown]
# ## Visualizations

# %%
from IPython.core.display import display, HTML
feature_set.loc[:,'Image'] = ["<img src='{}' width='50' height='50'>".format(i) for i in feature_set['Image']]
display(HTML(feature_set.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Contrast</th>
#       <th>Inverse Difference Moment</th>
#       <th>Energy</th>
#       <th>Entropy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src='OriginalBrodatz/D46.gif' width='50' ...</td>
#       <td>[189.474, 275.84, 158.114]</td>
#       <td>[0.224, 0.202, 0.22]</td>
#       <td>[0.051, 0.047, 0.051]</td>
#       <td>[-6.714, -6.909, -6.722]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src='OriginalBrodatz/D74.gif' width='50' ...</td>
#       <td>[763.787, 1378.434, 924.808]</td>
#       <td>[0.271, 0.228, 0.25]</td>
#       <td>[0.094, 0.086, 0.09]</td>
#       <td>[-6.84, -7.117, -6.97]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='OriginalBrodatz/D51.gif' width='50' ...</td>
#       <td>[1083.713, 1414.27, 383.962]</td>
#       <td>[0.248, 0.157, 0.229]</td>
#       <td>[0.066, 0.05, 0.06]</td>
#       <td>[-7.208, -7.521, -7.047]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='OriginalBrodatz/D107.gif' width='50'...</td>
#       <td>[1653.969, 2890.524, 1812.271]</td>
#       <td>[0.329, 0.287, 0.329]</td>
#       <td>[0.111, 0.1, 0.11]</td>
#       <td>[-6.397, -6.643, -6.444]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='OriginalBrodatz/D63.gif' width='50' ...</td>
#       <td>[264.155, 440.595, 282.949]</td>
#       <td>[0.186, 0.152, 0.18]</td>
#       <td>[0.056, 0.051, 0.055]</td>
#       <td>[-6.517, -6.749, -6.56]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='OriginalBrodatz/D89.gif' width='50' ...</td>
#       <td>[262.092, 522.639, 301.667]</td>
#       <td>[0.295, 0.256, 0.292]</td>
#       <td>[0.098, 0.092, 0.098]</td>
#       <td>[-6.238, -6.49, -6.284]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='OriginalBrodatz/D105.gif' width='50'...</td>
#       <td>[7274.132, 7887.85, 751.808]</td>
#       <td>[0.034, 0.031, 0.138]</td>
#       <td>[0.017, 0.016, 0.032]</td>
#       <td>[-8.694, -8.737, -7.97]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='OriginalBrodatz/D61.gif' width='50' ...</td>
#       <td>[294.172, 473.049, 310.287]</td>
#       <td>[0.174, 0.144, 0.17]</td>
#       <td>[0.039, 0.035, 0.038]</td>
#       <td>[-7.168, -7.39, -7.191]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img
td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src='OriginalBrodatz/D88.gif' width='50' ...</td>
#       <td>[187.345, 315.366, 188.072]</td>
#       <td>[0.337, 0.306, 0.338]</td>
#       <td>[0.099, 0.094, 0.099]</td>
#       <td>[-6.048, -6.215, -6.053]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><img src='OriginalBrodatz/D90.gif' width='50' ...</td>
#       <td>[118.906, 166.073, 110.495]</td>
#       <td>[0.256, 0.226, 0.257]</td>
#       <td>[0.052, 0.049, 0.052]</td>
#       <td>[-6.894, -7.048, -6.865]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><img src='OriginalBrodatz/D106.gif' width='50'...</td>
#       <td>[8654.089, 9169.822, 1016.342]</td>
#       <td>[0.027, 0.025, 0.124]</td>
#       <td>[0.019, 0.019, 0.036]</td>
#       <td>[-8.505, -8.539, -7.799]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td><img src='OriginalBrodatz/D43.gif' width='50' ...</td>
#       <td>[772.715, 881.24, 582.422]</td>
#       <td>[0.401, 0.382, 0.416]</td>
#       <td>[0.186, 0.181, 0.188]</td>
#       <td>[-4.447, -4.528, -4.422]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td><img src='OriginalBrodatz/D48.gif' width='50' ...</td>
#       <td>[32.229, 41.41, 31.241]</td>
#       <td>[0.362, 0.332, 0.365]</td>
#       <td>[0.072, 0.069, 0.072]</td>
#       <td>[-6.082, -6.19, -6.069]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td><img src='OriginalBrodatz/D59.gif' width='50' ...</td>
#       <td>[74.668, 116.876, 72.458]</td>
#       <td>[0.348, 0.31, 0.35]</td>
#       <td>[0.061, 0.057, 0.062]</td>
#       <td>[-6.515, -6.7, -6.512]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td><img src='OriginalBrodatz/D45.gif' width='50' ...</td>
#       <td>[664.105, 1197.314, 744.186]</td>
#       <td>[0.348, 0.32, 0.351]</td>
#       <td>[0.166, 0.159, 0.166]</td>
#       <td>[-4.938, -5.09, -4.963]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td><img src='OriginalBrodatz/D86.gif' width='50' ...</td>
#       <td>[844.993, 1857.516, 1016.586]</td>
#       <td>[0.127, 0.084, 0.112]</td>
#       <td>[0.028, 0.023, 0.027]</td>
#       <td>[-7.872, -8.221, -7.976]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td><img src='OriginalBrodatz/D110.gif' width='50'...</td>
#       <td>[2813.849, 3796.158, 2198.432]</td>
#       <td>[0.15, 0.129, 0.163]</td>
#       <td>[0.071, 0.064, 0.074]</td>
#       <td>[-7.159, -7.294, -7.075]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td><img src='OriginalBrodatz/D3.gif' width='50' h...</td>
#       <td>[1976.488, 2959.581, 2132.535]</td>
#       <td>[0.17, 0.148, 0.178]</td>
#       <td>[0.092, 0.083, 0.095]</td>
#       <td>[-6.962, -7.115, -6.951]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td><img src='OriginalBrodatz/D19.gif' width='50' ...</td>
#       <td>[618.822, 857.563, 559.408]</td>
#       <td>[0.108, 0.088, 0.109]</td>
#       <td>[0.041, 0.037, 0.041]</td>
#       <td>[-6.919, -7.077, -6.881]</td>
#     </

# %% [markdown]
# ___
